# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
gyro_outputt = pd.read_csv("0-90-0.csv")

# %%
gyro_output = gyro_outputt.iloc[312:]

# %%
gyro_output['index'] = range(len(gyro_output))
# Out:
# <ipython-input-36-7f7c623bdee2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gyro_output['index'] = range(len(gyro_output))

# %%
gyro_output_cpy = gyro_output

# %%
temperature = gyro_output.temperature

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_x"],label="ang_rate_x")
plt.plot(gyro_output["index"],gyro_output["ang_rate_y"],label="ang_rate_y")
plt.plot(gyro_output["index"],gyro_output["ang_rate_z"],label="ang_rate_z")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_x_1"],label="ang_rate_x_1")
plt.plot(gyro_output["index"],gyro_output["ang_rate_y_1"],label="ang_rate_y_1")
plt.plot(gyro_output["index"],gyro_output["ang_rate_z_1"],label="ang_rate_z_1")
plt.legend()
plt.show()

# %%
gyro_output.temperature.describe()
# Out:
# count     325.000000
# mean     5188.627692
# std        37.193519
# min      5104.000000
# 25%      5168.000000
# 50%      5184.000000
# 75%      5200.000000
# max      5296.000000
# Name: temperature, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["temperature"],label="temperature")
plt.plot(gyro_output["index"],[gyro_output.temperature.mean()]*len(gyro_output),label="temperature_mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.temperature.map(lambda p: p - gyro_output.temperature.mean()),label="temperature_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.ang_rate_x.describe()
# Out:
# count      325.000000
# mean     -5038.726154
# std       4400.084004
# min     -15168.000000
# 25%      -8881.000000
# 50%      -4809.000000
# 75%       -936.000000
# max       3369.000000
# Name: ang_rate_x, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_x"],label="ang_rate_x")
plt.plot(gyro_output["index"],[gyro_output.ang_rate_x.mean()]*len(gyro_output),label="ang_rate_x_mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_x.map(lambda p: p - gyro_output.ang_rate_x.mean()),label="ang_rate_x_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.ang_rate_y.describe()
# Out:
# count      325.000000
# mean      -174.295385
# std       1783.550838
# min      -3649.000000
# 25%       -897.000000
# 50%       -212.000000
# 75%         98.000000
# max      15661.000000
# Name: ang_rate_y, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_y"],label="ang_rate_y")
plt.plot(gyro_output["index"],[gyro_output.ang_rate_y.mean()]*len(gyro_output),label="ang_rate_y_mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_y.map(lambda p: p - gyro_output.ang_rate_y.mean()),label="ang_rate_y_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.ang_rate_z.describe()
# Out:
# count     325.000000
# mean      329.553846
# std       845.786164
# min     -2103.000000
# 25%      -111.000000
# 50%       200.000000
# 75%       959.000000
# max      2471.000000
# Name: ang_rate_z, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_z"],label="ang_rate_z")
plt.plot(gyro_output["index"],[gyro_output.ang_rate_z.mean()]*len(gyro_output),label="ang_rate_z_mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_z.map(lambda p: p - gyro_output.ang_rate_z.mean()),label="ang_rate_z_mean_deviation")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_x.map(lambda p: p - gyro_output.ang_rate_x.mean()),label="ang_rate_x_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.temperature_1.describe()
# Out:
# count     325.000000
# mean     4954.387692
# std        46.715423
# min      4816.000000
# 25%      4928.000000
# 50%      4944.000000
# 75%      4992.000000
# max      5072.000000
# Name: temperature_1, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["temperature_1"],label="temperature_1")
plt.plot(gyro_output["index"],[gyro_output.temperature_1.mean()]*len(gyro_output),label="mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.temperature_1.map(lambda p: p - gyro_output.temperature_1.mean()),label="temperature_1_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.ang_rate_x_1.describe()
# Out:
# count     325.000000
# mean     -227.313846
# std      1561.512594
# min     -8484.000000
# 25%      -523.000000
# 50%      -205.000000
# 75%       428.000000
# max      3235.000000
# Name: ang_rate_x_1, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_x_1"],label="ang_rate_x_1")
plt.plot(gyro_output["index"],[gyro_output.ang_rate_x_1.mean()]*len(gyro_output),label="mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_x_1.map(lambda p: p - gyro_output.ang_rate_x_1.mean()),label="ang_rate_x_1_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.ang_rate_y_1.describe()
# Out:
# count      325.000000
# mean     -5223.603077
# std       4384.992009
# min     -15346.000000
# 25%      -9038.000000
# 50%      -4975.000000
# 75%      -1102.000000
# max       3119.000000
# Name: ang_rate_y_1, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_y_1"],label="ang_rate_y_1")
plt.plot(gyro_output["index"],[gyro_output.ang_rate_y_1.mean()]*len(gyro_output),label="mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_y_1.map(lambda p: p - gyro_output.ang_rate_y_1.mean()),label="ang_rate_y_1_mean_deviation")
plt.legend()
plt.show()

# %%
gyro_output.ang_rate_z_1.describe()
# Out:
# count     325.000000
# mean      212.163077
# std       842.609447
# min     -2214.000000
# 25%      -210.000000
# 50%        82.000000
# 75%       843.000000
# max      2341.000000
# Name: ang_rate_z_1, dtype: float64

# %%
plt.plot(gyro_output["index"],gyro_output["ang_rate_z_1"],label="ang_rate_z_1")
plt.plot(gyro_output["index"],[gyro_output.ang_rate_z_1.mean()]*len(gyro_output),label="mean")
plt.legend()
plt.show()

# %%
plt.plot(gyro_output["index"],gyro_output.ang_rate_z_1.map(lambda p: p - gyro_output.ang_rate_z_1.mean()),label="ang_rate_z_1_mean_deviation")
plt.legend()
plt.show()
